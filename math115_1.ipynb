# %% [markdown]
# <a href="https://colab.research.google.com/github/chasbecker/BasicR/blob/main/math115_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import random as rd
import statistics as st

# %%
num_random_numbers = 100
min_value = 1
max_value = 100

random_numbers_list = [rd.randint(min_value, max_value) for _ in range(num_random_numbers)]

print(random_numbers_list)
# Out:
# [93, 91, 10, 54, 49, 88, 64, 66, 95, 26, 17, 40, 74, 60, 91, 6, 75, 21, 46, 74, 66, 66, 90, 80, 97, 15, 74, 43, 77, 19, 72, 49, 47, 11, 73, 26, 84, 34, 43, 66, 12, 86, 2, 44, 67, 73, 25, 6, 87, 15, 64, 51, 39, 30, 59, 34, 71, 84, 27, 94, 30, 11, 26, 77, 58, 50, 46, 80, 22, 53, 24, 75, 53, 64, 6, 68, 24, 50, 51, 62, 47, 17, 60, 7, 100, 48, 9, 90, 89, 77, 37, 50, 9, 66, 48, 36, 89, 1, 53, 71]

# %%
random_numbers_list.sort()
print(random_numbers_list)
# Out:
# [1, 2, 6, 6, 6, 7, 9, 9, 10, 11, 11, 12, 15, 15, 17, 17, 19, 21, 22, 24, 24, 25, 26, 26, 26, 27, 30, 30, 34, 34, 36, 37, 39, 40, 43, 43, 44, 46, 46, 47, 47, 48, 48, 49, 49, 50, 50, 50, 51, 51, 53, 53, 53, 54, 58, 59, 60, 60, 62, 64, 64, 64, 66, 66, 66, 66, 66, 67, 68, 71, 71, 72, 73, 73, 74, 74, 74, 75, 75, 77, 77, 77, 80, 80, 84, 84, 86, 87, 88, 89, 89, 90, 90, 91, 91, 93, 94, 95, 97, 100]

# %%
print(st.median(random_numbers_list))
# Out:
# 52.0

# %%
print(st.mean(random_numbers_list))
# Out:
# 51.76

# %%
print(st.mode(random_numbers_list))
# Out:
# 66
